# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !cd /kaggle/working

# Replace this path with the actual Kaggle input dataset path.
# !ls /kaggle/input/datasets/tiantian1zhang/bgm-priority1-gap-vs-fid-kaggle/bgm_priority1

# !cp -r /kaggle/input/datasets/tiantian1zhang/bgm-priority1-gap-vs-fid-kaggle/bgm_priority1 /kaggle/working
# Out:
# configs    README_COLAB.md	requirements_priority1.txt
# kaggle	   README_KAGGLE.md	requirements_strong.txt
# notebooks  README.md		scripts
# paper	   README_PRIORITY1.md	slurm

# %%
# !cd /kaggle/working/bgm_priority1
# !cd bgm_priority1
# Out:
# bgm_priority1

# %%
# !pip install -q -r /kaggle/working/bgm_priority1/requirements_priority1.txt

# %%
# !mkdir -p /kaggle/working/bgm_runs

# !cp -r /kaggle/working/bgm_priority1/outputs/cifar10_independent_pilot \
      /kaggle/working/bgm_runs/ 2>/dev/null || true

# !cp -r /kaggle/working/bgm_priority1/outputs/cifar10_minibatch_ot_pilot \
      /kaggle/working/bgm_runs/ 2>/dev/null || true

# %%
# !find /kaggle/working/bgm_runs -maxdepth 2 -name "summary.json" -print

# %%
# !cd /kaggle/working/bgm_priority1
import os
os.path.join("/kaggle/working/bgm_priority1")
# !cat /kaggle/working/bgm_priority1/kaggle/make_priority1_table.sh
# !bash /kaggle/working/bgm_priority1/kaggle/make_priority1_table.sh
# Out:
# #!/usr/bin/env bash
# set -euo pipefail
# python scripts/merge_gap_with_pilot_results.py \
#   --gap-csv /kaggle/working/bgm_runs/proxy_gap_cifar10/proxy_gap_summary.csv \
#   --runs-root /kaggle/working/bgm_runs \
#   --out-dir /kaggle/working/bgm_runs/priority1_gap_vs_fid
# python3: can't open file '/kaggle/working/scripts/merge_gap_with_pilot_results.py': [Errno 2] No such file or directory

# %%
! python /kaggle/working/bgm_priority1/scripts/merge_gap_with_pilot_results.py \
  --gap-csv /kaggle/working/bgm_runs/proxy_gap_cifar10/proxy_gap_summary.csv \
  --runs-root /kaggle/working/bgm_runs \
  --out-dir /kaggle/working/bgm_runs/priority1_gap_vs_fid

# %%
# !cd /kaggle/working/bgm_priority1 && PYTHONUNBUFFERED=1 bash kaggle/run_priority1_proxy_gap.sh 2>&1
# Out:
# 100%|█████████████████████████████████████████| 170M/170M [08:31<00:00, 333kB/s]
# seed=0 coupling=independent feature=downsample8+pca64 proxy_gap_auc=19.6232 elapsed=519.6s
# seed=0 coupling=minibatch_ot feature=downsample8+pca64 proxy_gap_auc=15.2015 elapsed=521.2s
# seed=1 coupling=independent feature=downsample8+pca64 proxy_gap_auc=19.8736 elapsed=2.9s
# seed=1 coupling=minibatch_ot feature=downsample8+pca64 proxy_gap_auc=15.3256 elapsed=4.5s
# seed=2 coupling=independent feature=downsample8+pca64 proxy_gap_auc=20.1326 elapsed=2.6s
# seed=2 coupling=minibatch_ot feature=downsample8+pca64 proxy_gap_auc=15.3985 elapsed=4.4s
# {
#   "args": {
#     "dataset": "cifar10",
#     "data_root": "/kaggle/working/data",
#     "download": true,
#     "dataset_max_samples": null,
#     "n": 1024,
#     "load_batch_size": 512,
#     "num_workers": 2,
#     "base_scale": 1.0,
#     "couplings": [
#       "independent",
#       "minibatch_ot"
#     ],
#     "ot_cost_space": "downsample8",
# ...

# %%
# !mkdir -p /kaggle/working/bgm_runs/cifar10_independent_pilot
# !mkdir -p /kaggle/working/bgm_runs/cifar10_minibatch_ot_pilot

# %%
# %%writefile /kaggle/working/bgm_runs/cifar10_independent_pilot/summary.json
# {
#   "dataset": "cifar10",
#   "coupling": "independent",
#   "steps": 20000,
#   "final_loss": 0.181840,
#   "fidelity": {
#     "inception_score_mean": 5.342547,
#     "frechet_inception_distance": 50.47966,
#     "kernel_inception_distance_mean": 0.04541688
#   }
# }
# Out:
# Overwriting /kaggle/working/bgm_runs/cifar10_independent_pilot/summary.json

# %%
# %%writefile /kaggle/working/bgm_runs/cifar10_minibatch_ot_pilot/summary.json
# {
#   "dataset": "cifar10",
#   "coupling": "minibatch_ot",
#   "steps": 20000,
#   "final_loss": 0.167806,
#   "fidelity": {
#     "inception_score_mean": 5.375590,
#     "frechet_inception_distance": 49.17263,
#     "kernel_inception_distance_mean": 0.04700630
#   }
# }
# Out:
# Writing /kaggle/working/bgm_runs/cifar10_minibatch_ot_pilot/summary.json

# %%
# !PYTHONUNBUFFERED=1 python /kaggle/working/bgm_priority1/scripts/merge_gap_with_pilot_results.py \
  --gap-csv /kaggle/working/bgm_runs/proxy_gap_cifar10/proxy_gap_summary.csv \
  --runs-root /kaggle/working/bgm_runs \
  --out-dir /kaggle/working/bgm_runs/priority1_gap_vs_fid 2>&1
# Out:
# {
#   "out_dir": "/kaggle/working/bgm_runs/priority1_gap_vs_fid",
#   "num_gap_rows": 2,
#   "num_run_dirs": 2,
#   "num_joined_rows": 2
# }

# %%
# !cat /kaggle/working/bgm_runs/priority1_gap_vs_fid/gap_vs_pilot_table.tex
# Out:
# % Auto-generated by scripts/merge_gap_with_pilot_results.py
# \begin{table}[t]
# \centering
# \small
# \caption{Priority-1 CIFAR-10 pilot: pre-training estimated proxy Markovization gap versus downstream pilot metrics. The proxy gap is estimated before neural training in a low-dimensional linear feature space; it is a design diagnostic, not a certified pixel-space lower bound.}
# \label{tab:cifar10_proxy_gap_vs_fid}
# \begin{tabular}{@{}llcccccc@{}}
# \toprule
# Dataset & Coupling & Proxy gap $\downarrow$ & Gap time & Train MSE $\downarrow$ & FID $\downarrow$ & KID $\downarrow$ & IS $\uparrow$ \\
# \midrule
# CIFAR10 & independent & 19.876 $\pm$ 0.255 & 8.8m & -- & 50.48 & 0.0454 & 5.34 \\
# CIFAR10 & minibatch OT & 15.309 $\pm$ 0.100 & 8.8m & -- & 49.17 & 0.0470 & 5.38 \\
# \bottomrule
# \end{tabular}
# \end{table}
